# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('anime.csv')

# %%
df.head()
# Out:
#           ID                                       Title Synonyms  \
# 21455  45064    Xiao Gongzhu Ai Wei La Yu Shenmi Wangguo  Unknown
# 21456  45065  Xiao Gongzhu Ai Wei La Yu Shenmi Wangguo 2  Unknown
# 21457  45059                     Yongzhe Chuang Mo Cheng  Unknown
# 21458  45063             Yu Shen Chuan: Wangzhe Shaonian  Unknown
# 21459  45061                               Konglong Wang  Unknown
#
#            Japanese                           English Synopsis   Type  \
# 21455   小公主艾薇拉与神秘王国          Princess and the Kingdom  Unknown  Movie
# 21456  小公主艾薇拉与神秘王国2  Avera and the Mystical Kingdom 2  Unknown  Movie
# 21457         勇者闯魔城                        Brave City  Unknown  Movie
# 21458      禹神传之王者少年           The Juvenile of King Yu  Unknown  Movie
# 21459           恐龙王                         Dino King  Unknown  Movie
#
#        Episodes           Status   Start_Aired  ...      Themes Demographics  \
# ...

# %%
df.tail()
# Out:
#           ID                                       Title Synonyms  \
# 21455  45064    Xiao Gongzhu Ai Wei La Yu Shenmi Wangguo  Unknown
# 21456  45065  Xiao Gongzhu Ai Wei La Yu Shenmi Wangguo 2  Unknown
# 21457  45059                     Yongzhe Chuang Mo Cheng  Unknown
# 21458  45063             Yu Shen Chuan: Wangzhe Shaonian  Unknown
# 21459  45061                               Konglong Wang  Unknown
#
#            Japanese                           English Synopsis   Type  \
# 21455   小公主艾薇拉与神秘王国          Princess and the Kingdom  Unknown  Movie
# 21456  小公主艾薇拉与神秘王国2  Avera and the Mystical Kingdom 2  Unknown  Movie
# 21457         勇者闯魔城                        Brave City  Unknown  Movie
# 21458      禹神传之王者少年           The Juvenile of King Yu  Unknown  Movie
# 21459           恐龙王                         Dino King  Unknown  Movie
#
#        Episodes           Status   Start_Aired  ...      Themes Demographics  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           ID                                       Title  \
# 0      16498                          Shingeki no Kyojin
# 1       1535                                  Death Note
# 2       5114            Fullmetal Alchemist: Brotherhood
# 3      30276                               One Punch Man
# 4      11757                            Sword Art Online
# ...      ...                                         ...
# 21455  45064    Xiao Gongzhu Ai Wei La Yu Shenmi Wangguo
# 21456  45065  Xiao Gongzhu Ai Wei La Yu Shenmi Wangguo 2
# 21457  45059                     Yongzhe Chuang Mo Cheng
# 21458  45063             Yu Shen Chuan: Wangzhe Shaonian
# 21459  45061                               Konglong Wang
#
#                                                 Synonyms  \
# 0                                               AoT, SnK
# 1                                                     DN
# 2      Hagane no Renkinjutsushi Fullmetal Alchemist, ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21460 entries, 0 to 21459
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                21460 non-null  int64
#  1   Title             21460 non-null  object
#  2   Synonyms          21460 non-null  object
#  3   Japanese          21460 non-null  object
#  4   English           21460 non-null  object
#  5   Synopsis          21460 non-null  object
#  6   Type              21460 non-null  object
#  7   Episodes          20913 non-null  float64
#  8   Status            21460 non-null  object
#  9   Start_Aired       21460 non-null  object
#  10  End_Aired         21460 non-null  object
#  11  Premiered         21460 non-null  object
#  12  Broadcast         21460 non-null  object
#  13  Producers         21460 non-null  object
#  14  Licensors         21460 non-null  object
#  15  Studios           21460 non-null  object
# ...

# %%
df.isnull()
# Out:
#           ID  Title  Synonyms  Japanese  English  Synopsis   Type  Episodes  \
# 0      False  False     False     False    False     False  False     False
# 1      False  False     False     False    False     False  False     False
# 2      False  False     False     False    False     False  False     False
# 3      False  False     False     False    False     False  False     False
# 4      False  False     False     False    False     False  False     False
# ...      ...    ...       ...       ...      ...       ...    ...       ...
# 21455  False  False     False     False    False     False  False     False
# 21456  False  False     False     False    False     False  False     False
# 21457  False  False     False     False    False     False  False     False
# 21458  False  False     False     False    False     False  False     False
# 21459  False  False     False     False    False     False  False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                     0
# Title                  0
# Synonyms               0
# Japanese               0
# English                0
# Synopsis               0
# Type                   0
# Episodes             547
# Status                 0
# Start_Aired            0
# End_Aired              0
# Premiered              0
# Broadcast              0
# Producers              0
# Licensors              0
# Studios                0
# Source                 0
# Genres                 0
# Themes                 0
# Demographics           0
# Duration_Minutes     599
# Rating                 0
# Score               6898
# Scored_Users        6898
# Ranked              1924
# Popularity             0
# Members                0
# Favorites              0
# dtype: int64

# %%
sns.histplot(x='Duration_Minutes',data= df,)
plt.show()

# %%
fig, ax = plt.subplots()
sns.histplot(x='Duration_Minutes',data=df)
print("minimuim duration",df["Duration_Minutes"].min())
print("maximuim duration",df["Duration_Minutes"].max())
ax.set_xlim(5,150)
ax.set_ylim(0,200)
plt.show()
# Out:
# minimuim duration 1.0
# maximuim duration 168.0

# %%
sns.rugplot(x='Episodes',data=df,height=50,color='darkblue')

sns.histplot(x='Episodes',data=df,kde=True)
# Out:
# <AxesSubplot:xlabel='Episodes', ylabel='Count'>

# %%
sns.boxplot(x=df['Episodes'])
# Out:
# <AxesSubplot:xlabel='Episodes'>

# %%
sns.boxplot(data=df.loc[:,['Episodes','Duration_Minutes']])
# Out:
# <AxesSubplot:>

# %%
import sklearn
from sklearn.datasets import

# %%
sns.kdeplot(df['Episodes'])
# Out:
# <AxesSubplot:xlabel='Episodes', ylabel='Density'>

# %%
plt.scatter (df.Episodes,df.Duration_Minutes)
plt.title('episodes vs watch hour')
plt.xlabel('Episodes')
plt.ylabel('Duration_Minutes')
# Out:
# Text(0, 0.5, 'Duration_Minutes')

# %%
df.corr()
# Out:
#                         ID  Episodes  Duration_Minutes     Score  \
# ID                1.000000 -0.013289         -0.266236 -0.061432
# Episodes         -0.013289  1.000000         -0.079195  0.072795
# Duration_Minutes -0.266236 -0.079195          1.000000  0.280253
# Score            -0.061432  0.072795          0.280253  1.000000
# Scored_Users      0.012874  0.049689          0.072051  0.393534
# Ranked            0.442588  0.007342         -0.239381 -0.977230
# Popularity        0.472173  0.034532         -0.229041 -0.689829
# Members          -0.070110  0.036801          0.071768  0.392046
# Favorites        -0.046161  0.051145          0.025552  0.238088
#
#                   Scored_Users    Ranked  Popularity   Members  Favorites
# ID                    0.012874  0.442588    0.472173 -0.070110  -0.046161
# Episodes              0.049689  0.007342    0.034532  0.036801   0.051145
# Duration_Minutes      0.072051 -0.239381   -0.229041  0.071768   0.025552
# ...

# %%
corr=df.corr()
sns.set(rc={'figure.figsize':(10,10)})
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x=df['Ranked'])
# Out:
# <AxesSubplot:xlabel='Ranked'>

# %%
sns.stripplot(x=df["Episodes"])
# Out:
# <AxesSubplot:xlabel='Episodes'>

# %%
df.describe(include='object')
# Out:
#                      Title Synonyms Japanese  English Synopsis   Type  \
# count                21460    21460    21460    21460    21460  21460
# unique               21460    11557    20473     8897    18505      7
# top     Shingeki no Kyojin  Unknown  Unknown  Unknown  Unknown     TV
# freq                     1     9280       62    12378     2718   6280
#
#                  Status Start_Aired      End_Aired Premiered Broadcast  \
# count             21460       21460          21460     21460     21460
# unique                3        8221           4796       238       569
# top     Finished Airing     Unknown  Not Available   Unknown   Unknown
# freq              20693         374          11261     16236     18316
#
#        Producers Licensors  Studios    Source   Genres   Themes Demographics  \
# count      21460     21460    21460     21460    21460    21460        21460
# unique      4158       261     1424        17      926      736           10
# ...
